# %%
import tensorflow as tf
from tensorflow import keras

import numpy as np 
import matplotlib.pyplot as plt

print(tf.__version__)
# Out:
# 1.13.0-dev20190111

# %% [markdown]
# The [Fashion MNIST dataset](https://github.com/zalandoresearch/fashion-mnist) is preferable to handwritten digit version because 1.) it's harder to archive near perfect classifications and, 2.) it's a better real word example.
#
# There are multiple methods for loading the fashion MNIST data. The keras dataset is helpful in that it returns tuples for training and test data.

# %%
fashion_mnist = keras.datasets.fashion_mnist

(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()

# %% [markdown]
# Labels are the numbers 0-9, but we will sometimes want to map these to the articles of clothing they represent.

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %% [markdown]
# Each pixel in input images is value from 0-255 but these need to be normalised to use as imput for the model.

# %%
train_images = train_images / 255.0
test_images = test_images / 255.0

# %% [markdown]
# Visualise the data to ensure it is correct.

# %%
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i], cmap=plt.cm.binary)
    plt.xlabel(class_names[train_labels[i]])

# %% [markdown]
# Building the model

# %%
baseline_model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(128, activation=tf.nn.relu),
    tf.keras.layers.Dense(10, activation=tf.nn.softmax)
])

baseline_model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy', 'sparse_categorical_crossentropy']
)

# %%
baseline_history = baseline_model.fit(train_images, train_labels, 
                                      epochs=20,
                                      validation_data=(test_images, test_labels),
                                      verbose=2)
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/20
# 60000/60000 - 5s - loss: 0.4977 - acc: 0.8257 - sparse_categorical_crossentropy: 0.4977 - val_loss: 0.4631 - val_acc: 0.8285 - val_sparse_categorical_crossentropy: 0.4631
# Epoch 2/20
# 60000/60000 - 5s - loss: 0.3777 - acc: 0.8639 - sparse_categorical_crossentropy: 0.3777 - val_loss: 0.3836 - val_acc: 0.8667 - val_sparse_categorical_crossentropy: 0.3836
# Epoch 3/20
# 60000/60000 - 5s - loss: 0.3395 - acc: 0.8766 - sparse_categorical_crossentropy: 0.3395 - val_loss: 0.3667 - val_acc: 0.8689 - val_sparse_categorical_crossentropy: 0.3667
# Epoch 4/20
# 60000/60000 - 5s - loss: 0.3148 - acc: 0.8850 - sparse_categorical_crossentropy: 0.3148 - val_loss: 0.3519 - val_acc: 0.8727 - val_sparse_categorical_crossentropy: 0.3519
# Epoch 5/20
# 60000/60000 - 5s - loss: 0.2953 - acc: 0.8918 - sparse_categorical_crossentropy: 0.2953 - val_loss: 0.3523 - val_acc: 0.8745 - val_sparse_categorical_crossentropy: 0.3523
# Epoch 6/20
# 60000/60000 - 5s - loss: 0.2800 - acc: 0.8964 - sparse_categorical_crossentropy: 0.2800 - val_loss: 0.3695 - val_acc: 0.8668 - val_sparse_categorical_crossentropy: 0.3695
# Epoch 7/20
# 60000/60000 - 5s - loss: 0.2689 - acc: 0.9000 - sparse_categorical_crossentropy: 0.2689 - val_loss: 0.3419 - val_acc: 0.8771 - val_sparse_categorical_crossentropy: 0.3419
# Epoch 8/20
# 60000/60000 - 5s - loss: 0.2562 - acc: 0.9056 - sparse_categorical_crossentropy: 0.2562 - val_loss: 0.3413 - val_acc: 0.8790 - val_sparse_categorical_crossentropy: 0.3413
# Epoch 9/20
# 60000/60000 - 5s - loss: 0.2463 - acc: 0.9083 - sparse_categorical_crossentropy: 0.2463 - val_loss: 0.3269 - val_acc: 0.8851 - val_sparse_categorical_crossentropy: 0.3269
# Epoch 10/20
# 60000/60000 - 5s - loss: 0.2363 - acc: 0.9115 - sparse_categorical_crossentropy: 0.2363 - val_loss: 0.3342 - val_acc: 0.8819 - val_sparse_categorical_crossentropy: 0.3342
# Epoch 11/20
# 60000/60000 - 5s - loss: 0.2281 - acc: 0.9143 - sparse_categorical_crossentropy: 0.2281 - val_loss: 0.3521 - val_acc: 0.8820 - val_sparse_categorical_crossentropy: 0.3521
# Epoch 12/20
# 60000/60000 - 5s - loss: 0.2208 - acc: 0.9169 - sparse_categorical_crossentropy: 0.2208 - val_loss: 0.3374 - val_acc: 0.8835 - val_sparse_categorical_crossentropy: 0.3374
# Epoch 13/20
# 60000/60000 - 5s - loss: 0.2159 - acc: 0.9188 - sparse_categorical_crossentropy: 0.2159 - val_loss: 0.3275 - val_acc: 0.8857 - val_sparse_categorical_crossentropy: 0.3275
# Epoch 14/20
# 60000/60000 - 5s - loss: 0.2085 - acc: 0.9218 - sparse_categorical_crossentropy: 0.2085 - val_loss: 0.3447 - val_acc: 0.8840 - val_sparse_categorical_crossentropy: 0.3447
# Epoch 15/20
# 60000/60000 - 5s - loss: 0.2026 - acc: 0.9231 - sparse_categorical_crossentropy: 0.2026 - val_loss: 0.3417 - val_acc: 0.8889 - val_sparse_categorical_crossentropy: 0.3417
# Epoch 16/20
# 60000/60000 - 5s - loss: 0.1944 - acc: 0.9266 - sparse_categorical_crossentropy: 0.1944 - val_loss: 0.3572 - val_acc: 0.8889 - val_sparse_categorical_crossentropy: 0.3572
# Epoch 17/20
# 60000/60000 - 5s - loss: 0.1903 - acc: 0.9287 - sparse_categorical_crossentropy: 0.1903 - val_loss: 0.3445 - val_acc: 0.8883 - val_sparse_categorical_crossentropy: 0.3445
# Epoch 18/20
# 60000/60000 - 5s - loss: 0.1859 - acc: 0.9302 - sparse_categorical_crossentropy: 0.1859 - val_loss: 0.3459 - val_acc: 0.8880 - val_sparse_categorical_crossentropy: 0.3459
# Epoch 19/20
# 60000/60000 - 5s - loss: 0.1794 - acc: 0.9328 - sparse_categorical_crossentropy: 0.1794 - val_loss: 0.3624 - val_acc: 0.8839 - val_sparse_categorical_crossentropy: 0.3624
# Epoch 20/20
# 60000/60000 - 5s - loss: 0.1765 - acc: 0.9325 - sparse_categorical_crossentropy: 0.1765 - val_loss: 0.3554 - val_acc: 0.8847 - val_sparse_categorical_crossentropy: 0.3554

# %%
smaller_model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(64, activation=tf.nn.relu),
    tf.keras.layers.Dense(10, activation=tf.nn.softmax)
])

smaller_model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy', 'sparse_categorical_crossentropy']
)

# %%
smaller_history = smaller_model.fit(train_images, train_labels, 
                                    epochs=20,
                                    validation_data=(test_images, test_labels),
                                    verbose=2)
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/20
# 60000/60000 - 4s - loss: 0.5146 - acc: 0.8217 - sparse_categorical_crossentropy: 0.5146 - val_loss: 0.4411 - val_acc: 0.8423 - val_sparse_categorical_crossentropy: 0.4411
# Epoch 2/20
# 60000/60000 - 4s - loss: 0.3931 - acc: 0.8604 - sparse_categorical_crossentropy: 0.3931 - val_loss: 0.4164 - val_acc: 0.8549 - val_sparse_categorical_crossentropy: 0.4164
# Epoch 3/20
# 60000/60000 - 4s - loss: 0.3552 - acc: 0.8732 - sparse_categorical_crossentropy: 0.3552 - val_loss: 0.3797 - val_acc: 0.8651 - val_sparse_categorical_crossentropy: 0.3797
# Epoch 4/20
# 60000/60000 - 4s - loss: 0.3312 - acc: 0.8809 - sparse_categorical_crossentropy: 0.3312 - val_loss: 0.3607 - val_acc: 0.8692 - val_sparse_categorical_crossentropy: 0.3607
# Epoch 5/20
# 60000/60000 - 4s - loss: 0.3122 - acc: 0.8864 - sparse_categorical_crossentropy: 0.3122 - val_loss: 0.3746 - val_acc: 0.8681 - val_sparse_categorical_crossentropy: 0.3746
# Epoch 6/20
# 60000/60000 - 4s - loss: 0.2983 - acc: 0.8907 - sparse_categorical_crossentropy: 0.2983 - val_loss: 0.3588 - val_acc: 0.8743 - val_sparse_categorical_crossentropy: 0.3588
# Epoch 7/20
# 60000/60000 - 4s - loss: 0.2867 - acc: 0.8951 - sparse_categorical_crossentropy: 0.2867 - val_loss: 0.3479 - val_acc: 0.8751 - val_sparse_categorical_crossentropy: 0.3479
# Epoch 8/20
# 60000/60000 - 4s - loss: 0.2814 - acc: 0.8960 - sparse_categorical_crossentropy: 0.2814 - val_loss: 0.3539 - val_acc: 0.8754 - val_sparse_categorical_crossentropy: 0.3539
# Epoch 9/20
# 60000/60000 - 4s - loss: 0.2702 - acc: 0.9004 - sparse_categorical_crossentropy: 0.2702 - val_loss: 0.3413 - val_acc: 0.8786 - val_sparse_categorical_crossentropy: 0.3413
# Epoch 10/20
# 60000/60000 - 4s - loss: 0.2611 - acc: 0.9029 - sparse_categorical_crossentropy: 0.2611 - val_loss: 0.3416 - val_acc: 0.8784 - val_sparse_categorical_crossentropy: 0.3416
# Epoch 11/20
# 60000/60000 - 4s - loss: 0.2548 - acc: 0.9057 - sparse_categorical_crossentropy: 0.2548 - val_loss: 0.3716 - val_acc: 0.8747 - val_sparse_categorical_crossentropy: 0.3716
# Epoch 12/20
# 60000/60000 - 4s - loss: 0.2473 - acc: 0.9074 - sparse_categorical_crossentropy: 0.2473 - val_loss: 0.3621 - val_acc: 0.8723 - val_sparse_categorical_crossentropy: 0.3621
# Epoch 13/20
# 60000/60000 - 4s - loss: 0.2431 - acc: 0.9102 - sparse_categorical_crossentropy: 0.2431 - val_loss: 0.3408 - val_acc: 0.8804 - val_sparse_categorical_crossentropy: 0.3408
# Epoch 14/20
# 60000/60000 - 4s - loss: 0.2345 - acc: 0.9128 - sparse_categorical_crossentropy: 0.2345 - val_loss: 0.3347 - val_acc: 0.8859 - val_sparse_categorical_crossentropy: 0.3347
# Epoch 15/20
# 60000/60000 - 4s - loss: 0.2307 - acc: 0.9142 - sparse_categorical_crossentropy: 0.2307 - val_loss: 0.3487 - val_acc: 0.8804 - val_sparse_categorical_crossentropy: 0.3487
# Epoch 16/20
# 60000/60000 - 4s - loss: 0.2248 - acc: 0.9160 - sparse_categorical_crossentropy: 0.2248 - val_loss: 0.3544 - val_acc: 0.8813 - val_sparse_categorical_crossentropy: 0.3544
# Epoch 17/20
# 60000/60000 - 4s - loss: 0.2201 - acc: 0.9177 - sparse_categorical_crossentropy: 0.2201 - val_loss: 0.3450 - val_acc: 0.8856 - val_sparse_categorical_crossentropy: 0.3450
# Epoch 18/20
# 60000/60000 - 4s - loss: 0.2155 - acc: 0.9192 - sparse_categorical_crossentropy: 0.2155 - val_loss: 0.3577 - val_acc: 0.8804 - val_sparse_categorical_crossentropy: 0.3577
# Epoch 19/20
# 60000/60000 - 4s - loss: 0.2124 - acc: 0.9201 - sparse_categorical_crossentropy: 0.2124 - val_loss: 0.3555 - val_acc: 0.8841 - val_sparse_categorical_crossentropy: 0.3555
# Epoch 20/20
# 60000/60000 - 4s - loss: 0.2077 - acc: 0.9227 - sparse_categorical_crossentropy: 0.2077 - val_loss: 0.3559 - val_acc: 0.8823 - val_sparse_categorical_crossentropy: 0.3559

# %%
higher_model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(256, activation=tf.nn.relu),
    tf.keras.layers.Dense(10, activation=tf.nn.softmax)
])

higher_model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy', 'sparse_categorical_crossentropy']
)

# %%
higher_history = higher_model.fit(train_images, train_labels, 
                                  epochs=20,
                                  validation_data=(test_images, test_labels),
                                  verbose=2)
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/20
# 60000/60000 - 8s - loss: 0.4797 - acc: 0.8286 - sparse_categorical_crossentropy: 0.4797 - val_loss: 0.4159 - val_acc: 0.8495 - val_sparse_categorical_crossentropy: 0.4159
# Epoch 2/20
# 60000/60000 - 7s - loss: 0.3615 - acc: 0.8679 - sparse_categorical_crossentropy: 0.3615 - val_loss: 0.3730 - val_acc: 0.8650 - val_sparse_categorical_crossentropy: 0.3730
# Epoch 3/20
# 60000/60000 - 8s - loss: 0.3264 - acc: 0.8806 - sparse_categorical_crossentropy: 0.3264 - val_loss: 0.3782 - val_acc: 0.8645 - val_sparse_categorical_crossentropy: 0.3782
# Epoch 4/20
# 60000/60000 - 7s - loss: 0.3012 - acc: 0.8876 - sparse_categorical_crossentropy: 0.3012 - val_loss: 0.3559 - val_acc: 0.8696 - val_sparse_categorical_crossentropy: 0.3559
# Epoch 5/20
# 60000/60000 - 9s - loss: 0.2843 - acc: 0.8948 - sparse_categorical_crossentropy: 0.2843 - val_loss: 0.3359 - val_acc: 0.8785 - val_sparse_categorical_crossentropy: 0.3359
# Epoch 6/20
# 60000/60000 - 7s - loss: 0.2708 - acc: 0.8978 - sparse_categorical_crossentropy: 0.2708 - val_loss: 0.3580 - val_acc: 0.8750 - val_sparse_categorical_crossentropy: 0.3580
# Epoch 7/20
# 60000/60000 - 8s - loss: 0.2588 - acc: 0.9029 - sparse_categorical_crossentropy: 0.2588 - val_loss: 0.3582 - val_acc: 0.8719 - val_sparse_categorical_crossentropy: 0.3582
# Epoch 8/20
# 60000/60000 - 8s - loss: 0.2488 - acc: 0.9071 - sparse_categorical_crossentropy: 0.2488 - val_loss: 0.3353 - val_acc: 0.8831 - val_sparse_categorical_crossentropy: 0.3353
# Epoch 9/20
# 60000/60000 - 8s - loss: 0.2372 - acc: 0.9096 - sparse_categorical_crossentropy: 0.2372 - val_loss: 0.3451 - val_acc: 0.8804 - val_sparse_categorical_crossentropy: 0.3451
# Epoch 10/20
# 60000/60000 - 9s - loss: 0.2250 - acc: 0.9159 - sparse_categorical_crossentropy: 0.2250 - val_loss: 0.3429 - val_acc: 0.8834 - val_sparse_categorical_crossentropy: 0.3429
# Epoch 11/20
# 60000/60000 - 8s - loss: 0.2200 - acc: 0.9168 - sparse_categorical_crossentropy: 0.2200 - val_loss: 0.3419 - val_acc: 0.8863 - val_sparse_categorical_crossentropy: 0.3419
# Epoch 12/20
# 60000/60000 - 9s - loss: 0.2111 - acc: 0.9191 - sparse_categorical_crossentropy: 0.2111 - val_loss: 0.3401 - val_acc: 0.8839 - val_sparse_categorical_crossentropy: 0.3401
# Epoch 13/20
# 60000/60000 - 8s - loss: 0.2042 - acc: 0.9227 - sparse_categorical_crossentropy: 0.2042 - val_loss: 0.3604 - val_acc: 0.8788 - val_sparse_categorical_crossentropy: 0.3604
# Epoch 14/20
# 60000/60000 - 8s - loss: 0.2012 - acc: 0.9243 - sparse_categorical_crossentropy: 0.2012 - val_loss: 0.3279 - val_acc: 0.8902 - val_sparse_categorical_crossentropy: 0.3279
# Epoch 15/20
# 60000/60000 - 8s - loss: 0.1910 - acc: 0.9279 - sparse_categorical_crossentropy: 0.1910 - val_loss: 0.3504 - val_acc: 0.8865 - val_sparse_categorical_crossentropy: 0.3504
# Epoch 16/20
# 60000/60000 - 8s - loss: 0.1839 - acc: 0.9298 - sparse_categorical_crossentropy: 0.1838 - val_loss: 0.3392 - val_acc: 0.8859 - val_sparse_categorical_crossentropy: 0.3392
# Epoch 17/20
# 60000/60000 - 8s - loss: 0.1810 - acc: 0.9315 - sparse_categorical_crossentropy: 0.1810 - val_loss: 0.3581 - val_acc: 0.8889 - val_sparse_categorical_crossentropy: 0.3581
# Epoch 18/20
# 60000/60000 - 8s - loss: 0.1747 - acc: 0.9331 - sparse_categorical_crossentropy: 0.1747 - val_loss: 0.3423 - val_acc: 0.8906 - val_sparse_categorical_crossentropy: 0.3423
# Epoch 19/20
# 60000/60000 - 7s - loss: 0.1677 - acc: 0.9373 - sparse_categorical_crossentropy: 0.1677 - val_loss: 0.3520 - val_acc: 0.8911 - val_sparse_categorical_crossentropy: 0.3520
# Epoch 20/20
# 60000/60000 - 8s - loss: 0.1654 - acc: 0.9374 - sparse_categorical_crossentropy: 0.1654 - val_loss: 0.3558 - val_acc: 0.8946 - val_sparse_categorical_crossentropy: 0.3558

# %%
def plot_history(histories, key='sparse_categorical_crossentropy'):
  plt.figure(figsize=(16,10))
    
  for name, history in histories:
    val = plt.plot(history.epoch, history.history['val_'+key],
                   '--', label=name.title()+' Val')
    plt.plot(history.epoch, history.history[key], color=val[0].get_color(),
             label=name.title()+' Train')

  plt.xlabel('Epochs')
  plt.ylabel(key.replace('_',' ').title())
  plt.legend()

  plt.xlim([0,max(history.epoch)])
    

plot_history([('baseline', baseline_history),
              ('smaller', smaller_history),
              ('higher', higher_history)])

# %%
baseline_model.evaluate(test_images, test_labels)
# Out:
# 10000/10000==============================] - 0s 31us/sample - loss: 0.3554 - acc: 0.8847 - sparse_categorical_crossentropy: 0.3554
# [0.3554029999256134, 0.8847, 0.35540304]

# %%
predictions = baseline_model.predict(np.expand_dims(test_images[0], 0))

np.argmax(predictions[0])
# Out:
# 9
